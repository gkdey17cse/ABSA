# %% [markdown]
# Code to generate embeddings of vector length 25 (run in Base environment)

# %%
import fasttext
import numpy as np
import pickle

# Define file paths
VOCAB_FILE = "vocab.txt"  # Path to the vocabulary file
OUTPUT_EMBEDDINGS_FILE = "fasttext_embeddings_25.pkl"  # Path to save embeddings

# Step 1: Train FastText Model
print("Training FastText model...")
model = fasttext.train_unsupervised(
    VOCAB_FILE, model="skipgram", dim=15
)  # Train with 50-dimensional embeddings
print("FastText model trained successfully.")

# Step 2: Load Vocabulary
with open(VOCAB_FILE, "r", encoding="utf-8") as f:
    words = f.read().splitlines()  # Read vocabulary file and split into words
print(f"Loaded vocabulary with {len(words)} words.")

# Step 3: Generate FastText Embeddings
print("Generating FastText embeddings...")
fasttext_embeddings = {}  # Dictionary to store word embeddings
for word in words:
    fasttext_embeddings[word] = model.get_word_vector(
        word
    ).tolist()  # Get embedding for each word
print(f"Generated embeddings for {len(fasttext_embeddings)} words.")

# Step 4: Handle Missing Words (if any)
embedding_dim = 25  # Dimension of FastText embeddings
all_vectors = np.array(
    list(fasttext_embeddings.values())
)  # Convert embeddings to a NumPy array
mean_vector = np.mean(all_vectors, axis=0)  # Compute mean vector of all embeddings

for word in words:
    if word not in fasttext_embeddings:  # If word is missing in FastText embeddings
        fasttext_embeddings[word] = mean_vector.tolist()  # Assign mean vector
print(f"Handled missing words (if any).")

# Step 5: Verify Embedding Dimensions
print("Verifying embedding dimensions...")
for word, embedding in fasttext_embeddings.items():
    if len(embedding) != embedding_dim:
        print(
            f"Error: Embedding for '{word}' has incorrect dimension {len(embedding)}."
        )
    else:
        print(f"Embedding for '{word}' has correct dimension {len(embedding)}.")

# Step 6: Save Embeddings
with open(OUTPUT_EMBEDDINGS_FILE, "wb") as f:
    pickle.dump(fasttext_embeddings, f)  # Save embeddings to a pickle file
print(f"FastText embeddings saved to {OUTPUT_EMBEDDINGS_FILE}.")
# Out:
# Training FastText model...
# FastText model trained successfully.
# Loaded vocabulary with 3867 words.
# Generating FastText embeddings...
# Generated embeddings for 3867 words.
# Handled missing words (if any).
# Verifying embedding dimensions...
# Error: Embedding for 'apples' has incorrect dimension 15.
# Error: Embedding for 'expect' has incorrect dimension 15.
# Error: Embedding for 'translucent' has incorrect dimension 15.
# Error: Embedding for 'appropriate' has incorrect dimension 15.
# Error: Embedding for 'lentil' has incorrect dimension 15.
# Error: Embedding for 'ARE' has incorrect dimension 15.
# Error: Embedding for 'time' has incorrect dimension 15.
# Error: Embedding for 'selected' has incorrect dimension 15.
# Error: Embedding for 'intimate' has incorrect dimension 15.
# Error: Embedding for 'MOSHPHERE' has incorrect dimension 15.
# Error: Embedding for 'marsala' has incorrect dimension 15.
# Error: Embedding for 'saturday' has incorrect dimension 15.
# Error: Embedding for 'Murrays' has incorrect dimension 15.
# Error: Embedding for 'undoubtedly' has incorrect dimension 15.
# Error: Embedding for 'greeting' has incorrect dimension 15.
# Error: Embedding for 'soggy' has incorrect dimension 15.
# Error: Embedding for 'thai' has incorrect dimension 15.
# Error: Embedding for 'Drinks' has incorrect dimension 15.
# Error: Embedding for 'checking' has incorrect dimension 15.
# Error: Embedding for 'add' has incorrect dimension 15.
# Error: Embedding for 'allow' has incorrect dimension 15.
# Error: Embedding for 'sun' has incorrect dimension 15.
# Error: Embedding for 'B' has incorrect dimension 15.
# Error: Embedding for 'planning' has incorrect dimension 15.
# Error: Embedding for 'tapas' has incorrect dimension 15.
# Error: Embedding for 'SEASONAL' has incorrect dimension 15.
# Error: Embedding for 'chopped' has incorrect dimension 15.
# Error: Embedding for 'City' has incorrect dimension 15.
# Error: Embedding for 'real' has incorrect dimension 15.
# Error: Embedding for 'style' has incorrect dimension 15.
# Error: Embedding for 'prepare' has incorrect dimension 15.
# Error: Embedding for 'baby' has incorrect dimension 15.
# Error: Embedding for 'spent' has incorrect dimension 15.
# Error: Embedding for '14.95' has incorrect dimension 15.
# Error: Embedding for 'Waitstaff' has incorrect dimension 15.
# Error: Embedding for '--' has incorrect dimension 15.
# Error: Embedding for 'Fridays' has incorrect dimension 15.
# Error: Embedding for 'coming' has incorrect dimension 15.
# Error: Embedding for 'chili' has incorrect dimension 15.
# Error: Embedding for '100' has incorrect dimension 15.
# Error: Embedding for 'mess' has incorrect dimension 15.
# Error: Embedding for 'THAT' has incorrect dimension 15.
# Error: Embedding for 'overpriced' has incorrect dimension 15.
# Error: Embedding for 'candle-light' has incorrect dimension 15.
# Error: Embedding for 'wake' has incorrect dimension 15.
# Error: Embedding for 'hear' has incorrect dimension 15.
# Error: Embedding for 'knew' has incorrect dimension 15.
# Error: Embedding for 'odd' has incorrect dimension 15.
# Error: Embedding for 'seasoning' has incorrect dimension 15.
# Error: Embedding for 'individuals' has incorrect dimension 15.
# Error: Embedding for 'gracious' has incorrect dimension 15.
# Error: Embedding for 'Definite' has incorrect dimension 15.
# Error: Embedding for 'super' has incorrect dimension 15.
# Error: Embedding for '45' has incorrect dimension 15.
# Error: Embedding for 'Gods' has incorrect dimension 15.
# Error: Embedding for 'sushi' has incorrect dimension 15.
# Error: Embedding for 'QPR' has incorrect dimension 15.
# Error: Embedding for 'Solid' has incorrect dimension 15.
# Error: Embedding for 'ton' has incorrect dimension 15.
# Error: Embedding for 'curtain' has incorrect dimension 15.
# Error: Embedding for 'you' has incorrect dimension 15.
# Error: Embedding for 'Frederick' has incorrect dimension 15.
# Error: Embedding for 'Most' has incorrect dimension 15.
# Error: Embedding for 'genuine' has incorrect dimension 15.
# Error: Embedding for 'hanger' has incorrect dimension 15.
# Error: Embedding for 'have' has incorrect dimension 15.
# Error: Embedding for 'DOLLARS' has incorrect dimension 15.
# Error: Embedding for 'Hyde' has incorrect dimension 15.
# Error: Embedding for 'Tan' has incorrect dimension 15.
# Error: Embedding for 'him' has incorrect dimension 15.
# Error: Embedding for 'popularity' has incorrect dimension 15.
# Error: Embedding for '13' has incorrect dimension 15.
# Error: Embedding for 'over' has incorrect dimension 15.
# Error: Embedding for 'world' has incorrect dimension 15.
# Error: Embedding for 'full' has incorrect dimension 15.
# Error: Embedding for 'bistro' has incorrect dimension 15.
# Error: Embedding for 'moreover' has incorrect dimension 15.
# Error: Embedding for 'recently' has incorrect dimension 15.
# Error: Embedding for 'main' has incorrect dimension 15.
# Error: Embedding for 'Scalina' has incorrect dimension 15.
# Error: Embedding for 'students' has incorrect dimension 15.
# Error: Embedding for 'sad-looking' has incorrect dimension 15.
# Error: Embedding for 'mom' has incorrect dimension 15.
# Error: Embedding for 'palets' has incorrect dimension 15.
# Error: Embedding for 'do' has incorrect dimension 15.
# Error: Embedding for 'location' has incorrect dimension 15.
# Error: Embedding for 'pumkin' has incorrect dimension 15.
# Error: Embedding for 'La' has incorrect dimension 15.
# Error: Embedding for 'show' has incorrect dimension 15.
# Error: Embedding for 'lacked' has incorrect dimension 15.
# Error: Embedding for 'okra' has incorrect dimension 15.
# Error: Embedding for 'Grill' has incorrect dimension 15.
# Error: Embedding for 'fellow' has incorrect dimension 15.
# Error: Embedding for 'partly' has incorrect dimension 15.
# Error: Embedding for 'marinated' has incorrect dimension 15.
# Error: Embedding for 'hip' has incorrect dimension 15.
# Error: Embedding for 'Made' has incorrect dimension 15.
# Error: Embedding for 'appetizing' has incorrect dimension 15.
# Error: Embedding for 'reservation' has incorrect dimension 15.
# Error: Embedding for 'enjoying' has incorrect dimension 15.
# Error: Embedding for 'homemade' has incorrect dimension 15.
# Error: Embedding for 'ever-changing' has incorrect dimension 15.
# Error: Embedding for 'touristy' has incorrect dimension 15.
# Error: Embedding for 'greens' has incorrect dimension 15.
# Error: Embedding for 'offered' has incorrect dimension 15.
# Error: Embedding for 'frozen' has incorrect dimension 15.
# Error: Embedding for 'club' has incorrect dimension 15.
# Error: Embedding for 'pressured' has incorrect dimension 15.
# Error: Embedding for 'played' has incorrect dimension 15.
# Error: Embedding for 'Disappointing' has incorrect dimension 15.
# Error: Embedding for 'advance' has incorrect dimension 15.
# Error: Embedding for 'worry' has incorrect dimension 15.
# Error: Embedding for 'Izakaya' has incorrect dimension 15.
# Error: Embedding for 'top-notch' has incorrect dimension 15.
# Error: Embedding for '8:00' has incorrect dimension 15.
# Error: Embedding for 'thinking' has incorrect dimension 15.
# Error: Embedding for 'That' has incorrect dimension 15.
# Error: Embedding for 'tasty' has incorrect dimension 15.
# Error: Embedding for 'street' has incorrect dimension 15.
# Error: Embedding for 'be' has incorrect dimension 15.
# Error: Embedding for 'naan' has incorrect dimension 15.
# Error: Embedding for 'unexpected' has incorrect dimension 15.
# Error: Embedding for 'Add' has incorrect dimension 15.
# Error: Embedding for 'entered' has incorrect dimension 15.
# Error: Embedding for 'Puree' has incorrect dimension 15.
# Error: Embedding for 'Price' has incorrect dimension 15.
# Error: Embedding for 'Highly' has incorrect dimension 15.
# Error: Embedding for 'awful' has incorrect dimension 15.
# Error: Embedding for 'oh' has incorrect dimension 15.
# Error: Embedding for 'entre'es' has incorrect dimension 15.
# Error: Embedding for '50' has incorrect dimension 15.
# Error: Embedding for 'snacking' has incorrect dimension 15.
# Error: Embedding for 'small' has incorrect dimension 15.
# Error: Embedding for 'ew' has incorrect dimension 15.
# Error: Embedding for 'smaller' has incorrect dimension 15.
# Error: Embedding for '9' has incorrect dimension 15.
# Error: Embedding for 'rainy' has incorrect dimension 15.
# Error: Embedding for 'groups' has incorrect dimension 15.
# Error: Embedding for 'call' has incorrect dimension 15.
# Error: Embedding for 'fondue' has incorrect dimension 15.
# Error: Embedding for 'owner' has incorrect dimension 15.
# Error: Embedding for 'kicker' has incorrect dimension 15.
# Error: Embedding for 'Cashew' has incorrect dimension 15.
# Error: Embedding for 'all' has incorrect dimension 15.
# Error: Embedding for 'interesting' has incorrect dimension 15.
# Error: Embedding for 'Free' has incorrect dimension 15.
# Error: Embedding for 'enough' has incorrect dimension 15.
# Error: Embedding for 'turned' has incorrect dimension 15.
# Error: Embedding for 'cooked' has incorrect dimension 15.
# Error: Embedding for 'Tamarind' has incorrect dimension 15.
# Error: Embedding for 'unconventional' has incorrect dimension 15.
# Error: Embedding for 'potential' has incorrect dimension 15.
# Error: Embedding for 'friendlier' has incorrect dimension 15.
# Error: Embedding for 'drinks' has incorrect dimension 15.
# Error: Embedding for 'Wow' has incorrect dimension 15.
# Error: Embedding for 'Disney' has incorrect dimension 15.
# Error: Embedding for 'variety' has incorrect dimension 15.
# Error: Embedding for 'In' has incorrect dimension 15.
# Error: Embedding for 'favor' has incorrect dimension 15.
# Error: Embedding for 'apt' has incorrect dimension 15.
# Error: Embedding for 'Mulino' has incorrect dimension 15.
# Error: Embedding for 'st.' has incorrect dimension 15.
# Error: Embedding for 'Nolita' has incorrect dimension 15.
# Error: Embedding for 'Definitely' has incorrect dimension 15.
# Error: Embedding for 'she's-way-cuter-than-me-that-b' has incorrect dimension 15.
# Error: Embedding for 'happened' has incorrect dimension 15.
# Error: Embedding for '1st' has incorrect dimension 15.
# Error: Embedding for 'seeming' has incorrect dimension 15.
# Error: Embedding for 'imitation' has incorrect dimension 15.
# Error: Embedding for 'recommend' has incorrect dimension 15.
# Error: Embedding for 'gari' has incorrect dimension 15.
# Error: Embedding for 'Do' has incorrect dimension 15.
# Error: Embedding for 'sketchy' has incorrect dimension 15.
# Error: Embedding for 'lag' has incorrect dimension 15.
# Error: Embedding for 'price' has incorrect dimension 15.
# Error: Embedding for 'LS' has incorrect dimension 15.
# Error: Embedding for 'big' has incorrect dimension 15.
# Error: Embedding for 'ambience' has incorrect dimension 15.
# Error: Embedding for 'Pastrami' has incorrect dimension 15.
# Error: Embedding for 'shared' has incorrect dimension 15.
# Error: Embedding for 'REAL' has incorrect dimension 15.
# Error: Embedding for 'Herky' has incorrect dimension 15.
# Error: Embedding for 'writing' has incorrect dimension 15.
# Error: Embedding for 'goodness' has incorrect dimension 15.
# Error: Embedding for 'approached' has incorrect dimension 15.
# Error: Embedding for 'lawns' has incorrect dimension 15.
# Error: Embedding for 'resembled' has incorrect dimension 15.
# Error: Embedding for 'take' has incorrect dimension 15.
# Error: Embedding for 'Yes' has incorrect dimension 15.
# Error: Embedding for 'ones' has incorrect dimension 15.
# Error: Embedding for 'lobster' has incorrect dimension 15.
# Error: Embedding for 'then' has incorrect dimension 15.
# Error: Embedding for 'working' has incorrect dimension 15.
# Error: Embedding for 'pits' has incorrect dimension 15.
# Error: Embedding for 'hanging' has incorrect dimension 15.
# Error: Embedding for 'taj' has incorrect dimension 15.
# Error: Embedding for 'Has' has incorrect dimension 15.
# Error: Embedding for 'Roth' has incorrect dimension 15.
# Error: Embedding for 'Based' has incorrect dimension 15.
# Error: Embedding for 'myself' has incorrect dimension 15.
# Error: Embedding for 'Terrible' has incorrect dimension 15.
# Error: Embedding for 'neglected' has incorrect dimension 15.
# Error: Embedding for 'overated' has incorrect dimension 15.
# Error: Embedding for 'amid' has incorrect dimension 15.
# Error: Embedding for 'near-by' has incorrect dimension 15.
# Error: Embedding for 'brought' has incorrect dimension 15.
# Error: Embedding for 'bagels' has incorrect dimension 15.
# Error: Embedding for 'give' has incorrect dimension 15.
# Error: Embedding for 'disappoint' has incorrect dimension 15.
# Error: Embedding for 'rivals' has incorrect dimension 15.
# Error: Embedding for 'satisfied' has incorrect dimension 15.
# Error: Embedding for 'positive' has incorrect dimension 15.
# Error: Embedding for 'caprese' has incorrect dimension 15.
# Error: Embedding for 'noon' has incorrect dimension 15.
# Error: Embedding for 'Dim' has incorrect dimension 15.
# Error: Embedding for 'st' has incorrect dimension 15.
# Error: Embedding for '12-14' has incorrect dimension 15.
# Error: Embedding for 'sent' has incorrect dimension 15.
# Error: Embedding for 'pork' has incorrect dimension 15.
# Error: Embedding for 'shout' has incorrect dimension 15.
# Error: Embedding for 'going' has incorrect dimension 15.
# Error: Embedding for ''ino' has incorrect dimension 15.
# Error: Embedding for 'creme' has incorrect dimension 15.
# Error: Embedding for 'noodles' has incorrect dimension 15.
# Error: Embedding for 'large' has incorrect dimension 15.
# Error: Embedding for '28' has incorrect dimension 15.
# Error: Embedding for 'overly' has incorrect dimension 15.
# Error: Embedding for 'quasi-thai' has incorrect dimension 15.
# Error: Embedding for 'establishment' has incorrect dimension 15.
# Error: Embedding for 'steaks' has incorrect dimension 15.
# Error: Embedding for 'expresso' has incorrect dimension 15.
# Error: Embedding for 'bunch' has incorrect dimension 15.
# Error: Embedding for 'English' has incorrect dimension 15.
# Error: Embedding for 'chin' has incorrect dimension 15.
# Error: Embedding for 'snobby' has incorrect dimension 15.
# Error: Embedding for 'reason' has incorrect dimension 15.
# Error: Embedding for 'tip' has incorrect dimension 15.
# Error: Embedding for 'inludes' has incorrect dimension 15.
# Error: Embedding for 'eclectic' has incorrect dimension 15.
# Error: Embedding for 'Fun' has incorrect dimension 15.
# Error: Embedding for 'tower' has incorrect dimension 15.
# Error: Embedding for 'challenge' has incorrect dimension 15.
# Error: Embedding for 'atmoshpere' has incorrect dimension 15.
# Error: Embedding for 'parmesean' has incorrect dimension 15.
# Error: Embedding for 'unfriendly' has incorrect dimension 15.
# Error: Embedding for 'Chance' has incorrect dimension 15.
# Error: Embedding for 'serve' has incorrect dimension 15.
# Error: Embedding for 'flaky' has incorrect dimension 15.
# Error: Embedding for 'lambchops' has incorrect dimension 15.
# Error: Embedding for 'by' has incorrect dimension 15.
# Error: Embedding for 'thin-crust' has incorrect dimension 15.
# Error: Embedding for 'diamond' has incorrect dimension 15.
# Error: Embedding for 'proprietor' has incorrect dimension 15.
# Error: Embedding for 'without' has incorrect dimension 15.
# Error: Embedding for 'foggy' has incorrect dimension 15.
# Error: Embedding for 'Italian-' has incorrect dimension 15.
# Error: Embedding for '161' has incorrect dimension 15.
# Error: Embedding for 'down' has incorrect dimension 15.
# Error: Embedding for 'card' has incorrect dimension 15.
# Error: Embedding for '7' has incorrect dimension 15.
# Error: Embedding for 'corner' has incorrect dimension 15.
# Error: Embedding for 'Got' has incorrect dimension 15.
# Error: Embedding for 'sans' has incorrect dimension 15.
# Error: Embedding for 'mashed' has incorrect dimension 15.
# Error: Embedding for 'noticed' has incorrect dimension 15.
# Error: Embedding for 'charts' has incorrect dimension 15.
# Error: Embedding for 'refreshing' has incorrect dimension 15.
# Error: Embedding for 'sushimi' has incorrect dimension 15.
# Error: Embedding for 'personality' has incorrect dimension 15.
# Error: Embedding for 'Scopa' has incorrect dimension 15.
# Error: Embedding for 'palate' has incorrect dimension 15.
# Error: Embedding for 'screwed' has incorrect dimension 15.
# Error: Embedding for 'drumsticks' has incorrect dimension 15.
# Error: Embedding for 'decoration' has incorrect dimension 15.
# Error: Embedding for 'lousy' has incorrect dimension 15.
# Error: Embedding for 'impresses' has incorrect dimension 15.
# Error: Embedding for 'toasted' has incorrect dimension 15.
# Error: Embedding for 'feeling' has incorrect dimension 15.
# Error: Embedding for 'accustomed' has incorrect dimension 15.
# Error: Embedding for 'comment' has incorrect dimension 15.
# Error: Embedding for 'hurt' has incorrect dimension 15.
# Error: Embedding for 'recognize' has incorrect dimension 15.
# Error: Embedding for 'flavour' has incorrect dimension 15.
# Error: Embedding for 'space' has incorrect dimension 15.
# Error: Embedding for 'listed' has incorrect dimension 15.
# Error: Embedding for 'wheat' has incorrect dimension 15.
# Error: Embedding for 'chef' has incorrect dimension 15.
# Error: Embedding for 'LOVED' has incorrect dimension 15.
# Error: Embedding for 'find' has incorrect dimension 15.
# Error: Embedding for 'humble' has incorrect dimension 15.
# Error: Embedding for 'decent' has incorrect dimension 15.
# Error: Embedding for 'Although' has incorrect dimension 15.
# Error: Embedding for 'quality' has incorrect dimension 15.
# Error: Embedding for 'voluminous' has incorrect dimension 15.
# Error: Embedding for 'cakes' has incorrect dimension 15.
# Error: Embedding for 'except' has incorrect dimension 15.
# Error: Embedding for 'stuffy' has incorrect dimension 15.
# Error: Embedding for 'tiem' has incorrect dimension 15.
# Error: Embedding for 'e' has incorrect dimension 15.
# Error: Embedding for 'impecable' has incorrect dimension 15.
# Error: Embedding for 'Hudson' has incorrect dimension 15.
# Error: Embedding for 'nothing' has incorrect dimension 15.
# Error: Embedding for 'disappointment' has incorrect dimension 15.
# Error: Embedding for 'unobtrusive' has incorrect dimension 15.
# Error: Embedding for 'anywhere' has incorrect dimension 15.
# Error: Embedding for 'chocolate' has incorrect dimension 15.
# Error: Embedding for 'ordered' has incorrect dimension 15.
# Error: Embedding for 'outta' has incorrect dimension 15.
# Error: Embedding for 'sweetness' has incorrect dimension 15.
# Error: Embedding for 'hosting' has incorrect dimension 15.
# Error: Embedding for '-even' has incorrect dimension 15.
# Error: Embedding for 'who' has incorrect dimension 15.
# Error: Embedding for 'Joya' has incorrect dimension 15.
# Error: Embedding for 'visitor' has incorrect dimension 15.
# Error: Embedding for 'rose' has incorrect dimension 15.
# Error: Embedding for 'lived' has incorrect dimension 15.
# Error: Embedding for 'mark' has incorrect dimension 15.
# Error: Embedding for 'popular' has incorrect dimension 15.
# Error: Embedding for 'raucous' has incorrect dimension 15.
# Error: Embedding for 'costs' has incorrect dimension 15.
# Error: Embedding for 'things' has incorrect dimension 15.
# Error: Embedding for 'boldness' has incorrect dimension 15.
# Error: Embedding for 'terrific' has incorrect dimension 15.
# Error: Embedding for 'recent' has incorrect dimension 15.
# Error: Embedding for 'unaccommodating' has incorrect dimension 15.
# Error: Embedding for 'Decent' has incorrect dimension 15.
# Error: Embedding for 'bass' has incorrect dimension 15.
# Error: Embedding for 'following' has incorrect dimension 15.
# Error: Embedding for 'Tokyo' has incorrect dimension 15.
# Error: Embedding for 'concern' has incorrect dimension 15.
# Error: Embedding for 'other' has incorrect dimension 15.
# Error: Embedding for 'choices' has incorrect dimension 15.
# Error: Embedding for ''pub' has incorrect dimension 15.
# Error: Embedding for 'When' has incorrect dimension 15.
# Error: Embedding for 'supposed' has incorrect dimension 15.
# Error: Embedding for 'Over' has incorrect dimension 15.
# Error: Embedding for 'into' has incorrect dimension 15.
# Error: Embedding for 'pastas' has incorrect dimension 15.
# Error: Embedding for 'same' has incorrect dimension 15.
# Error: Embedding for 'frist' has incorrect dimension 15.
# Error: Embedding for 'CHEAP' has incorrect dimension 15.
# Error: Embedding for 'roofdeck' has incorrect dimension 15.
# Error: Embedding for 'South' has incorrect dimension 15.
# Error: Embedding for 'vow' has incorrect dimension 15.
# Error: Embedding for 'usher' has incorrect dimension 15.
# Error: Embedding for 'Eating' has incorrect dimension 15.
# Error: Embedding for 'before' has incorrect dimension 15.
# Error: Embedding for 'wo' has incorrect dimension 15.
# Error: Embedding for 'photos' has incorrect dimension 15.
# Error: Embedding for 'Butter' has incorrect dimension 15.
# Error: Embedding for 'bruschettas' has incorrect dimension 15.
# Error: Embedding for 'faired' has incorrect dimension 15.
# Error: Embedding for 'B+' has incorrect dimension 15.
# Error: Embedding for 'list' has incorrect dimension 15.
# Error: Embedding for 'fare' has incorrect dimension 15.
# Error: Embedding for 'trendi' has incorrect dimension 15.
# Error: Embedding for 'growing' has incorrect dimension 15.
# Error: Embedding for 'brings' has incorrect dimension 15.
# Error: Embedding for 'flavor' has incorrect dimension 15.
# Error: Embedding for 'instantly' has incorrect dimension 15.
# Error: Embedding for 'free' has incorrect dimension 15.
# Error: Embedding for 'pretty' has incorrect dimension 15.
# Error: Embedding for 'pastrami' has incorrect dimension 15.
# Error: Embedding for 's' has incorrect dimension 15.
# Error: Embedding for 'generously' has incorrect dimension 15.
# Error: Embedding for 'Gelato' has incorrect dimension 15.
# Error: Embedding for 'while' has incorrect dimension 15.
# Error: Embedding for 'dissappointed' has incorrect dimension 15.
# Error: Embedding for 'SEA' has incorrect dimension 15.
# Error: Embedding for 'tracks' has incorrect dimension 15.
# Error: Embedding for 'well-executed' has incorrect dimension 15.
# Error: Embedding for 'thawed' has incorrect dimension 15.
# Error: Embedding for 'seems' has incorrect dimension 15.
# Error: Embedding for 'easy' has incorrect dimension 15.
# Error: Embedding for 'colleague' has incorrect dimension 15.
# Error: Embedding for 'possible' has incorrect dimension 15.
# Error: Embedding for 'cash' has incorrect dimension 15.
# Error: Embedding for 'o.k.' has incorrect dimension 15.
# Error: Embedding for 'summer-eat' has incorrect dimension 15.
# Error: Embedding for 'England' has incorrect dimension 15.
# Error: Embedding for 'inexpensive' has incorrect dimension 15.
# Error: Embedding for 'Just' has incorrect dimension 15.
# Error: Embedding for 'pack' has incorrect dimension 15.
# Error: Embedding for 'busy' has incorrect dimension 15.
# Error: Embedding for 'terrine' has incorrect dimension 15.
# Error: Embedding for 'second' has incorrect dimension 15.
# Error: Embedding for 'quick-cooked' has incorrect dimension 15.
# Error: Embedding for 'door' has incorrect dimension 15.
# Error: Embedding for 'ridding' has incorrect dimension 15.
# Error: Embedding for 'heavy' has incorrect dimension 15.
# Error: Embedding for 'offer' has incorrect dimension 15.
# Error: Embedding for 'winter' has incorrect dimension 15.
# Error: Embedding for 'Jersey' has incorrect dimension 15.
# Error: Embedding for 'champagne' has incorrect dimension 15.
# Error: Embedding for 'Haru' has incorrect dimension 15.
# Error: Embedding for 'waitressing' has incorrect dimension 15.
# Error: Embedding for 'Ess-a' has incorrect dimension 15.
# Error: Embedding for '2.50' has incorrect dimension 15.
# Error: Embedding for 'servants' has incorrect dimension 15.
# Error: Embedding for 'CARE' has incorrect dimension 15.
# Error: Embedding for 'innovative' has incorrect dimension 15.
# Error: Embedding for 'grab' has incorrect dimension 15.
# Error: Embedding for 'wasabe' has incorrect dimension 15.
# Error: Embedding for 'nicely' has incorrect dimension 15.
# Error: Embedding for 'lady' has incorrect dimension 15.
# Error: Embedding for 'whatsoever' has incorrect dimension 15.
# Error: Embedding for 'beautifully' has incorrect dimension 15.
# Error: Embedding for 'mini' has incorrect dimension 15.
# Error: Embedding for 'belly' has incorrect dimension 15.
# Error: Embedding for 'appears' has incorrect dimension 15.
# Error: Embedding for 'visit' has incorrect dimension 15.
# Error: Embedding for 'heaven' has incorrect dimension 15.
# Error: Embedding for 'girls' has incorrect dimension 15.
# Error: Embedding for 'piece' has incorrect dimension 15.
# Error: Embedding for 'maybe' has incorrect dimension 15.
# Error: Embedding for '2-person' has incorrect dimension 15.
# Error: Embedding for 'Our' has incorrect dimension 15.
# Error: Embedding for 'packaged' has incorrect dimension 15.
# Error: Embedding for 'anyways' has incorrect dimension 15.
# Error: Embedding for 'foie' has incorrect dimension 15.
# Error: Embedding for 'lobby' has incorrect dimension 15.
# Error: Embedding for 'gem' has incorrect dimension 15.
# Error: Embedding for 'been' has incorrect dimension 15.
# Error: Embedding for 'lemon' has incorrect dimension 15.
# Error: Embedding for 'trout' has incorrect dimension 15.
# Error: Embedding for 'literally' has incorrect dimension 15.
# Error: Embedding for 'upstairs' has incorrect dimension 15.
# Error: Embedding for 'extreme' has incorrect dimension 15.
# Error: Embedding for 'approximately' has incorrect dimension 15.
# Error: Embedding for 'versus' has incorrect dimension 15.
# Error: Embedding for 'bridge' has incorrect dimension 15.
# Error: Embedding for 'breezy' has incorrect dimension 15.
# Error: Embedding for 'features' has incorrect dimension 15.
# Error: Embedding for 'lot' has incorrect dimension 15.
# Error: Embedding for 'messy' has incorrect dimension 15.
# Error: Embedding for 'Brooklyn' has incorrect dimension 15.
# Error: Embedding for 'green' has incorrect dimension 15.
# Error: Embedding for 'Thali' has incorrect dimension 15.
# Error: Embedding for 'wild' has incorrect dimension 15.
# Error: Embedding for 'men' has incorrect dimension 15.
# Error: Embedding for '2003' has incorrect dimension 15.
# Error: Embedding for 'offeres' has incorrect dimension 15.
# Error: Embedding for 'generic' has incorrect dimension 15.
# Error: Embedding for 'tables' has incorrect dimension 15.
# Error: Embedding for 'traffic' has incorrect dimension 15.
# Error: Embedding for 'grew' has incorrect dimension 15.
# Error: Embedding for 'hall' has incorrect dimension 15.
# Error: Embedding for 'REALLY' has incorrect dimension 15.
# Error: Embedding for '6.25' has incorrect dimension 15.
# Error: Embedding for 'gummy' has incorrect dimension 15.
# Error: Embedding for 'Usually' has incorrect dimension 15.
# Error: Embedding for 'yorkie' has incorrect dimension 15.
# Error: Embedding for 'swirl' has incorrect dimension 15.
# Error: Embedding for 'incompetency' has incorrect dimension 15.
# Error: Embedding for 'design' has incorrect dimension 15.
# Error: Embedding for 'these' has incorrect dimension 15.
# Error: Embedding for 'checked' has incorrect dimension 15.
# Error: Embedding for 'Ballato' has incorrect dimension 15.
# Error: Embedding for 'wish' has incorrect dimension 15.
# Error: Embedding for 'summer' has incorrect dimension 15.
# Error: Embedding for 'boarderline' has incorrect dimension 15.
# Error: Embedding for 'drink' has incorrect dimension 15.
# Error: Embedding for 'Upon' has incorrect dimension 15.
# Error: Embedding for 'Super' has incorrect dimension 15.
# Error: Embedding for 'values' has incorrect dimension 15.
# Error: Embedding for 'dinnertime' has incorrect dimension 15.
# Error: Embedding for 'Cakebread' has incorrect dimension 15.
# Error: Embedding for 'crowds' has incorrect dimension 15.
# Error: Embedding for 'remind' has incorrect dimension 15.
# Error: Embedding for 'early' has incorrect dimension 15.
# Error: Embedding for 'Zabars' has incorrect dimension 15.
# Error: Embedding for 'unless' has incorrect dimension 15.
# Error: Embedding for 'ziti' has incorrect dimension 15.
# Error: Embedding for 'Quality' has incorrect dimension 15.
# Error: Embedding for 'COMPACT' has incorrect dimension 15.
# Error: Embedding for 'transported' has incorrect dimension 15.
# Error: Embedding for 'affected' has incorrect dimension 15.
# Error: Embedding for 'turnip' has incorrect dimension 15.
# Error: Embedding for 'airport' has incorrect dimension 15.
# Error: Embedding for 'marine' has incorrect dimension 15.
# Error: Embedding for 'porridge' has incorrect dimension 15.
# Error: Embedding for 'bucks' has incorrect dimension 15.
# Error: Embedding for 'interested' has incorrect dimension 15.
# Error: Embedding for '2-for' has incorrect dimension 15.
# Error: Embedding for 'unheralded' has incorrect dimension 15.
# Error: Embedding for 'Spice' has incorrect dimension 15.
# Error: Embedding for 'MUST' has incorrect dimension 15.
# Error: Embedding for 'intermediate' has incorrect dimension 15.
# Error: Embedding for 'benches' has incorrect dimension 15.
# Error: Embedding for 'Lahore' has incorrect dimension 15.
# Error: Embedding for 'unimposing' has incorrect dimension 15.
# Error: Embedding for 'rather' has incorrect dimension 15.
# Error: Embedding for 'during' has incorrect dimension 15.
# Error: Embedding for 'Pad' has incorrect dimension 15.
# Error: Embedding for 'four' has incorrect dimension 15.
# Error: Embedding for 'sophistication' has incorrect dimension 15.
# Error: Embedding for 'extraordinary' has incorrect dimension 15.
# Error: Embedding for 'thoroughly' has incorrect dimension 15.
# Error: Embedding for 'Late' has incorrect dimension 15.
# Error: Embedding for 'become' has incorrect dimension 15.
# Error: Embedding for 'meetings' has incorrect dimension 15.
# Error: Embedding for 'significant' has incorrect dimension 15.
# Error: Embedding for 'Square' has incorrect dimension 15.
# Error: Embedding for 'award' has incorrect dimension 15.
# Error: Embedding for 'empty' has incorrect dimension 15.
# Error: Embedding for 'reasonably' has incorrect dimension 15.
# Error: Embedding for 'picks' has incorrect dimension 15.
# Error: Embedding for 'delectable' has incorrect dimension 15.
# Error: Embedding for 'critic' has incorrect dimension 15.
# Error: Embedding for 'warm' has incorrect dimension 15.
# Error: Embedding for 'Blue' has incorrect dimension 15.
# Error: Embedding for 'contrast' has incorrect dimension 15.
# Error: Embedding for '30th' has incorrect dimension 15.
# Error: Embedding for 'concerned' has incorrect dimension 15.
# Error: Embedding for 'obliged' has incorrect dimension 15.
# Error: Embedding for 'scallops' has incorrect dimension 15.
# Error: Embedding for 'fillings' has incorrect dimension 15.
# Error: Embedding for 'parathas' has incorrect dimension 15.
# Error: Embedding for 'Nevertheless' has incorrect dimension 15.
# Error: Embedding for 'rude' has incorrect dimension 15.
# Error: Embedding for 'yasuda' has incorrect dimension 15.
# Error: Embedding for 'nevertheless' has incorrect dimension 15.
# Error: Embedding for 'playing' has incorrect dimension 15.
# Error: Embedding for 'fatty' has incorrect dimension 15.
# Error: Embedding for 'stopped' has incorrect dimension 15.
# Error: Embedding for 'lava' has incorrect dimension 15.
# Error: Embedding for 'server' has incorrect dimension 15.
# Error: Embedding for 'Calcutta' has incorrect dimension 15.
# Error: Embedding for 'Salmon' has incorrect dimension 15.
# Error: Embedding for 'she' has incorrect dimension 15.
# Error: Embedding for 'someone' has incorrect dimension 15.
# Error: Embedding for 'However' has incorrect dimension 15.
# Error: Embedding for 'sense' has incorrect dimension 15.
# Error: Embedding for 'know' has incorrect dimension 15.
# Error: Embedding for 'stacks' has incorrect dimension 15.
# Error: Embedding for 'Though' has incorrect dimension 15.
# Error: Embedding for 'Ambience' has incorrect dimension 15.
# Error: Embedding for 'save' has incorrect dimension 15.
# Error: Embedding for 'gave' has incorrect dimension 15.
# Error: Embedding for 'section' has incorrect dimension 15.
# Error: Embedding for 'experience' has incorrect dimension 15.
# Error: Embedding for 'frequently' has incorrect dimension 15.
# Error: Embedding for 'blasted' has incorrect dimension 15.
# Error: Embedding for 'hospitable' has incorrect dimension 15.
# Error: Embedding for 'Mondays' has incorrect dimension 15.
# Error: Embedding for 'japanese' has incorrect dimension 15.
# Error: Embedding for 'ie' has incorrect dimension 15.
# Error: Embedding for 'always' has incorrect dimension 15.
# Error: Embedding for 'limited' has incorrect dimension 15.
# Error: Embedding for 'including' has incorrect dimension 15.
# Error: Embedding for 'Top' has incorrect dimension 15.
# Error: Embedding for 'apppetizers' has incorrect dimension 15.
# Error: Embedding for 'cake' has incorrect dimension 15.
# Error: Embedding for 'california' has incorrect dimension 15.
# Error: Embedding for 'point' has incorrect dimension 15.
# Error: Embedding for 'Shanghai' has incorrect dimension 15.
# Error: Embedding for 'needed' has incorrect dimension 15.
# Error: Embedding for 'staples' has incorrect dimension 15.
# Error: Embedding for 'Dahkin' has incorrect dimension 15.
# Error: Embedding for 'St.' has incorrect dimension 15.
# Error: Embedding for 'venture' has incorrect dimension 15.
# Error: Embedding for 'sample' has incorrect dimension 15.
# Error: Embedding for 'freshwater' has incorrect dimension 15.
# Error: Embedding for 'over-bearing' has incorrect dimension 15.
# Error: Embedding for 'aanother' has incorrect dimension 15.
# Error: Embedding for 'minimalist' has incorrect dimension 15.
# Error: Embedding for 'squeezed' has incorrect dimension 15.
# Error: Embedding for 'Diner' has incorrect dimension 15.
# Error: Embedding for 'Nuts' has incorrect dimension 15.
# Error: Embedding for 'feature' has incorrect dimension 15.
# Error: Embedding for 'benedict' has incorrect dimension 15.
# Error: Embedding for 'surprisingly' has incorrect dimension 15.
# Error: Embedding for 'West' has incorrect dimension 15.
# Error: Embedding for 'vegetarian' has incorrect dimension 15.
# Error: Embedding for 'Se-Ew' has incorrect dimension 15.
# Error: Embedding for 'sit' has incorrect dimension 15.
# Error: Embedding for 'later' has incorrect dimension 15.
# Error: Embedding for 'adds' has incorrect dimension 15.
# Error: Embedding for 'threw' has incorrect dimension 15.
# Error: Embedding for 'group' has incorrect dimension 15.
# Error: Embedding for 'seat' has incorrect dimension 15.
# Error: Embedding for 'corn' has incorrect dimension 15.
# Error: Embedding for 'brassiere' has incorrect dimension 15.
# Error: Embedding for 'Mignon' has incorrect dimension 15.
# Error: Embedding for 'whole' has incorrect dimension 15.
# Error: Embedding for 'situated' has incorrect dimension 15.
# Error: Embedding for 'taken' has incorrect dimension 15.
# Error: Embedding for 'pathetic' has incorrect dimension 15.
# Error: Embedding for 'Chinatown' has incorrect dimension 15.
# Error: Embedding for 'mean' has incorrect dimension 15.
# Error: Embedding for 'understands' has incorrect dimension 15.
# Error: Embedding for 'root' has incorrect dimension 15.
# Error: Embedding for 'companionship' has incorrect dimension 15.
# Error: Embedding for 'breads' has incorrect dimension 15.
# Error: Embedding for 'spare' has incorrect dimension 15.
# Error: Embedding for 'buck' has incorrect dimension 15.
# Error: Embedding for 'barely' has incorrect dimension 15.
# Error: Embedding for 'said' has incorrect dimension 15.
# Error: Embedding for 'preparing' has incorrect dimension 15.
# Error: Embedding for 'mozzarella' has incorrect dimension 15.
# Error: Embedding for 'Zero' has incorrect dimension 15.
# Error: Embedding for 'meatballs' has incorrect dimension 15.
# Error: Embedding for 'sesame' has incorrect dimension 15.
# Error: Embedding for 'takeout' has incorrect dimension 15.
# Error: Embedding for 'cooking' has incorrect dimension 15.
# Error: Embedding for 'deliveries' has incorrect dimension 15.
# Error: Embedding for 'Angel' has incorrect dimension 15.
# Error: Embedding for 'scrumptious' has incorrect dimension 15.
# Error: Embedding for 'impressed' has incorrect dimension 15.
# Error: Embedding for 'Time' has incorrect dimension 15.
# Error: Embedding for 'inconsistent' has incorrect dimension 15.
# Error: Embedding for 'only' has incorrect dimension 15.
# Error: Embedding for 'trying' has incorrect dimension 15.
# Error: Embedding for 'Tanya' has incorrect dimension 15.
# Error: Embedding for 'assortment' has incorrect dimension 15.
# Error: Embedding for 'simple' has incorrect dimension 15.
# Error: Embedding for 'chic' has incorrect dimension 15.
# Error: Embedding for 'preparation' has incorrect dimension 15.
# Error: Embedding for 'citysearch' has incorrect dimension 15.
# Error: Embedding for 'roxy' has incorrect dimension 15.
# Error: Embedding for 'doors' has incorrect dimension 15.
# Error: Embedding for 'Told' has incorrect dimension 15.
# Error: Embedding for 'Lived' has incorrect dimension 15.
# Error: Embedding for 'dark' has incorrect dimension 15.
# Error: Embedding for 'Bass' has incorrect dimension 15.
# Error: Embedding for 'Edamame' has incorrect dimension 15.
# Error: Embedding for 'assorted' has incorrect dimension 15.
# Error: Embedding for 'stop' has incorrect dimension 15.
# Error: Embedding for 'deemed' has incorrect dimension 15.
# Error: Embedding for 'ate' has incorrect dimension 15.
# Error: Embedding for 'dealt' has incorrect dimension 15.
# Error: Embedding for 'classics' has incorrect dimension 15.
# Error: Embedding for 'hold' has incorrect dimension 15.
# Error: Embedding for 'fill' has incorrect dimension 15.
# Error: Embedding for 'extensive' has incorrect dimension 15.
# Error: Embedding for 'well' has incorrect dimension 15.
# Error: Embedding for 'limp' has incorrect dimension 15.
# Error: Embedding for 'son' has incorrect dimension 15.
# Error: Embedding for 'Taiwanese' has incorrect dimension 15.
# Error: Embedding for 'ride' has incorrect dimension 15.
# Error: Embedding for 'roti' has incorrect dimension 15.
# Error: Embedding for 'off' has incorrect dimension 15.
# Error: Embedding for 'asbolute' has incorrect dimension 15.
# Error: Embedding for 'Try' has incorrect dimension 15.
# Error: Embedding for 'stands' has incorrect dimension 15.
# Error: Embedding for 'COZY' has incorrect dimension 15.
# Error: Embedding for 'worth' has incorrect dimension 15.
# Error: Embedding for 'beer' has incorrect dimension 15.
# Error: Embedding for 'Tal' has incorrect dimension 15.
# Error: Embedding for 'People' has incorrect dimension 15.
# Error: Embedding for 'precisely' has incorrect dimension 15.
# Error: Embedding for 'NYC' has incorrect dimension 15.
# Error: Embedding for 'beautiful' has incorrect dimension 15.
# Error: Embedding for 'kababs' has incorrect dimension 15.
# Error: Embedding for 'together' has incorrect dimension 15.
# Error: Embedding for 'Italy' has incorrect dimension 15.
# Error: Embedding for 'DF' has incorrect dimension 15.
# Error: Embedding for 'gotten' has incorrect dimension 15.
# Error: Embedding for 'snapple' has incorrect dimension 15.
# Error: Embedding for 'tasts' has incorrect dimension 15.
# Error: Embedding for 'delayed' has incorrect dimension 15.
# Error: Embedding for ''perks' has incorrect dimension 15.
# Error: Embedding for 'experiance' has incorrect dimension 15.
# Error: Embedding for 'hesititate' has incorrect dimension 15.
# Error: Embedding for '.....' has incorrect dimension 15.
# Error: Embedding for 'figured' has incorrect dimension 15.
# Error: Embedding for 'jalapeno' has incorrect dimension 15.
# Error: Embedding for 'figs' has incorrect dimension 15.
# Error: Embedding for 'largest' has incorrect dimension 15.
# Error: Embedding for ''ve' has incorrect dimension 15.
# Error: Embedding for 'visited' has incorrect dimension 15.
# Error: Embedding for 'sardines' has incorrect dimension 15.
# Error: Embedding for 'ALL' has incorrect dimension 15.
# Error: Embedding for 'much' has incorrect dimension 15.
# Error: Embedding for 'Costco' has incorrect dimension 15.
# Error: Embedding for 'Bar' has incorrect dimension 15.
# Error: Embedding for 'Not' has incorrect dimension 15.
# Error: Embedding for 'suggested' has incorrect dimension 15.
# Error: Embedding for 'piping' has incorrect dimension 15.
# Error: Embedding for 'unlike' has incorrect dimension 15.
# Error: Embedding for 'frantic' has incorrect dimension 15.
# Error: Embedding for 'building' has incorrect dimension 15.
# Error: Embedding for 'ethnic' has incorrect dimension 15.
# Error: Embedding for 'edibility' has incorrect dimension 15.
# Error: Embedding for 'spread' has incorrect dimension 15.
# Error: Embedding for 'set' has incorrect dimension 15.
# Error: Embedding for 'ACTORS' has incorrect dimension 15.
# Error: Embedding for 'burned' has incorrect dimension 15.
# Error: Embedding for 'staff' has incorrect dimension 15.
# Error: Embedding for 'rarity' has incorrect dimension 15.
# Error: Embedding for 'pinot' has incorrect dimension 15.
# Error: Embedding for 'Sapphire' has incorrect dimension 15.
# Error: Embedding for 'perfection' has incorrect dimension 15.
# Error: Embedding for 'famous' has incorrect dimension 15.
# Error: Embedding for 'Chennai' has incorrect dimension 15.
# Error: Embedding for 'expert' has incorrect dimension 15.
# Error: Embedding for 'about' has incorrect dimension 15.
# Error: Embedding for 'facing' has incorrect dimension 15.
# Error: Embedding for 'pieces' has incorrect dimension 15.
# Error: Embedding for 'oily' has incorrect dimension 15.
# Error: Embedding for 'Priced' has incorrect dimension 15.
# Error: Embedding for 'draw' has incorrect dimension 15.
# Error: Embedding for 'idle' has incorrect dimension 15.
# Error: Embedding for 'option' has incorrect dimension 15.
# Error: Embedding for 'points' has incorrect dimension 15.
# Error: Embedding for 'Once' has incorrect dimension 15.
# Error: Embedding for 'Even' has incorrect dimension 15.
# Error: Embedding for 'magnificant' has incorrect dimension 15.
# Error: Embedding for 'Bombay' has incorrect dimension 15.
# Error: Embedding for 'drinking' has incorrect dimension 15.
# Error: Embedding for 'parties' has incorrect dimension 15.
# Error: Embedding for 'garlic' has incorrect dimension 15.
# Error: Embedding for 'skip' has incorrect dimension 15.
# Error: Embedding for 'dare' has incorrect dimension 15.
# Error: Embedding for 'bright' has incorrect dimension 15.
# Error: Embedding for 'death' has incorrect dimension 15.
# Error: Embedding for 'mouth' has incorrect dimension 15.
# Error: Embedding for 'strong' has incorrect dimension 15.
# Error: Embedding for 'pray' has incorrect dimension 15.
# Error: Embedding for 'Only' has incorrect dimension 15.
# Error: Embedding for 'passing' has incorrect dimension 15.
# Error: Embedding for 'hurry' has incorrect dimension 15.
# Error: Embedding for 'spectacular' has incorrect dimension 15.
# Error: Embedding for 'he' has incorrect dimension 15.
# Error: Embedding for 'excited' has incorrect dimension 15.
# Error: Embedding for 'melts' has incorrect dimension 15.
# Error: Embedding for 'paninis' has incorrect dimension 15.
# Error: Embedding for 'classical' has incorrect dimension 15.
# Error: Embedding for 'Pub' has incorrect dimension 15.
# Error: Embedding for 'interior' has incorrect dimension 15.
# Error: Embedding for 'Long' has incorrect dimension 15.
# Error: Embedding for 'shrimp' has incorrect dimension 15.
# Error: Embedding for 'souffle' has incorrect dimension 15.
# Error: Embedding for 'previews' has incorrect dimension 15.
# Error: Embedding for 'pita' has incorrect dimension 15.
# Error: Embedding for 'engine' has incorrect dimension 15.
# Error: Embedding for 'Sichuan' has incorrect dimension 15.
# Error: Embedding for 'encouraged' has incorrect dimension 15.
# Error: Embedding for 'presented' has incorrect dimension 15.
# Error: Embedding for 'Sara' has incorrect dimension 15.
# Error: Embedding for 'texture' has incorrect dimension 15.
# Error: Embedding for 'none' has incorrect dimension 15.
# Error: Embedding for 'mild' has incorrect dimension 15.
# Error: Embedding for 'beverage' has incorrect dimension 15.
# Error: Embedding for 'regular' has incorrect dimension 15.
# Error: Embedding for 'Chicken' has incorrect dimension 15.
# Error: Embedding for 'finishing' has incorrect dimension 15.
# Error: Embedding for 'malai' has incorrect dimension 15.
# Error: Embedding for 'Five' has incorrect dimension 15.
# Error: Embedding for 'PORTIONS' has incorrect dimension 15.
# Error: Embedding for 'provided' has incorrect dimension 15.
# Error: Embedding for 'Patroon' has incorrect dimension 15.
# Error: Embedding for 'ot' has incorrect dimension 15.
# Error: Embedding for 'HUGE' has incorrect dimension 15.
# Error: Embedding for 'Hats' has incorrect dimension 15.
# Error: Embedding for 'enter' has incorrect dimension 15.
# Error: Embedding for 'DO' has incorrect dimension 15.
# Error: Embedding for 'completely' has incorrect dimension 15.
# Error: Embedding for 'works' has incorrect dimension 15.
# Error: Embedding for 'nothingon' has incorrect dimension 15.
# Error: Embedding for 'skimpy' has incorrect dimension 15.
# Error: Embedding for 'hours' has incorrect dimension 15.
# Error: Embedding for 'touch' has incorrect dimension 15.
# Error: Embedding for 'hand-crafted' has incorrect dimension 15.
# Error: Embedding for 'BTs' has incorrect dimension 15.
# Error: Embedding for 'whatever' has incorrect dimension 15.
# Error: Embedding for 'adequate' has incorrect dimension 15.
# Error: Embedding for 'accent' has incorrect dimension 15.
# Error: Embedding for 'tanks' has incorrect dimension 15.
# Error: Embedding for 'crab' has incorrect dimension 15.
# Error: Embedding for 'bench' has incorrect dimension 15.
# Error: Embedding for 'topping' has incorrect dimension 15.
# Error: Embedding for 'non-busy' has incorrect dimension 15.
# Error: Embedding for 'substantial' has incorrect dimension 15.
# Error: Embedding for 'everyone' has incorrect dimension 15.
# Error: Embedding for 'conclusion' has incorrect dimension 15.
# Error: Embedding for 'side' has incorrect dimension 15.
# Error: Embedding for 'closely' has incorrect dimension 15.
# Error: Embedding for 'dined' has incorrect dimension 15.
# Error: Embedding for 'light' has incorrect dimension 15.
# Error: Embedding for 'nebbiolo' has incorrect dimension 15.
# Error: Embedding for '11' has incorrect dimension 15.
# Error: Embedding for 'drive' has incorrect dimension 15.
# Error: Embedding for 'roast' has incorrect dimension 15.
# Error: Embedding for 'lifetime' has incorrect dimension 15.
# Error: Embedding for 'share' has incorrect dimension 15.
# Error: Embedding for 'pistachio' has incorrect dimension 15.
# Error: Embedding for 'Nothing' has incorrect dimension 15.
# Error: Embedding for 'roasted' has incorrect dimension 15.
# Error: Embedding for 'based' has incorrect dimension 15.
# Error: Embedding for 'month' has incorrect dimension 15.
# Error: Embedding for 'Behind' has incorrect dimension 15.
# Error: Embedding for 'Perhaps' has incorrect dimension 15.
# Error: Embedding for 'nudged' has incorrect dimension 15.
# Error: Embedding for 'digestive' has incorrect dimension 15.
# Error: Embedding for 'even' has incorrect dimension 15.
# Error: Embedding for 'chewy' has incorrect dimension 15.
# Error: Embedding for 'lie' has incorrect dimension 15.
# Error: Embedding for 'dates' has incorrect dimension 15.
# Error: Embedding for 'gathered' has incorrect dimension 15.
# Error: Embedding for 'loving' has incorrect dimension 15.
# Error: Embedding for 'nigiri' has incorrect dimension 15.
# Error: Embedding for 'could' has incorrect dimension 15.
# Error: Embedding for 'complimentary' has incorrect dimension 15.
# Error: Embedding for 'written' has incorrect dimension 15.
# Error: Embedding for 'new' has incorrect dimension 15.
# Error: Embedding for 'tap' has incorrect dimension 15.
# Error: Embedding for 'short-term' has incorrect dimension 15.
# Error: Embedding for 'from' has incorrect dimension 15.
# Error: Embedding for 'lies' has incorrect dimension 15.
# Error: Embedding for 'class' has incorrect dimension 15.
# Error: Embedding for 'unable' has incorrect dimension 15.
# Error: Embedding for 'March' has incorrect dimension 15.
# Error: Embedding for 'midtown' has incorrect dimension 15.
# Error: Embedding for 'weeks' has incorrect dimension 15.
# Error: Embedding for 'bargain' has incorrect dimension 15.
# Error: Embedding for 'sicilian' has incorrect dimension 15.
# Error: Embedding for 'imported' has incorrect dimension 15.
# Error: Embedding for 'Curry' has incorrect dimension 15.
# Error: Embedding for 'load' has incorrect dimension 15.
# ...
# Error: Embedding for 'Mexican' has incorrect dimension 15.
# Error: Embedding for 'ya' has incorrect dimension 15.
# Error: Embedding for 'table' has incorrect dimension 15.
# Error: Embedding for 'dank' has incorrect dimension 15.
# Error: Embedding for 'deep' has incorrect dimension 15.
# Error: Embedding for 'knish' has incorrect dimension 15.
# Error: Embedding for 'lover' has incorrect dimension 15.
# Error: Embedding for 'daft' has incorrect dimension 15.
# Error: Embedding for 'bagel' has incorrect dimension 15.
# Error: Embedding for 'One' has incorrect dimension 15.
# Error: Embedding for 'Ave' has incorrect dimension 15.
# Error: Embedding for 'flavors' has incorrect dimension 15.
# Error: Embedding for 'Rolls' has incorrect dimension 15.
# Error: Embedding for 'doughy' has incorrect dimension 15.
# Error: Embedding for 'grilled' has incorrect dimension 15.
# Error: Embedding for 'least' has incorrect dimension 15.
# Error: Embedding for 'Liang' has incorrect dimension 15.
# Error: Embedding for 'contract' has incorrect dimension 15.
# Error: Embedding for 'After' has incorrect dimension 15.
# Error: Embedding for 'friend' has incorrect dimension 15.
# Error: Embedding for 'restaurant' has incorrect dimension 15.
# Error: Embedding for 'Bread' has incorrect dimension 15.
# Error: Embedding for 'pick' has incorrect dimension 15.
# Error: Embedding for 'band' has incorrect dimension 15.
# Error: Embedding for 'found' has incorrect dimension 15.
# Error: Embedding for 'tell' has incorrect dimension 15.
# Error: Embedding for 'cell' has incorrect dimension 15.
# Error: Embedding for 'use' has incorrect dimension 15.
# Error: Embedding for 'standing' has incorrect dimension 15.
# Error: Embedding for 'tasted' has incorrect dimension 15.
# Error: Embedding for 'buds' has incorrect dimension 15.
# Error: Embedding for 'reconsider' has incorrect dimension 15.
# Error: Embedding for 'Their' has incorrect dimension 15.
# Error: Embedding for 'quickly' has incorrect dimension 15.
# Error: Embedding for 'dainty' has incorrect dimension 15.
# Error: Embedding for 'Pair' has incorrect dimension 15.
# Error: Embedding for 'keep' has incorrect dimension 15.
# Error: Embedding for 'reservations' has incorrect dimension 15.
# Error: Embedding for '3' has incorrect dimension 15.
# Error: Embedding for 'manhathan' has incorrect dimension 15.
# Error: Embedding for 'leaf' has incorrect dimension 15.
# Error: Embedding for 'We' has incorrect dimension 15.
# Error: Embedding for 'F' has incorrect dimension 15.
# Error: Embedding for 'fresher' has incorrect dimension 15.
# Error: Embedding for 'Taiwan' has incorrect dimension 15.
# Error: Embedding for 'sunday' has incorrect dimension 15.
# Error: Embedding for 'pre-fixe' has incorrect dimension 15.
# Error: Embedding for 'overcooked' has incorrect dimension 15.
# Error: Embedding for 'was' has incorrect dimension 15.
# Error: Embedding for 'flavorful' has incorrect dimension 15.
# Error: Embedding for 'not-so-fresh' has incorrect dimension 15.
# Error: Embedding for 'scatty' has incorrect dimension 15.
# Error: Embedding for 'consistant' has incorrect dimension 15.
# Error: Embedding for 'icing' has incorrect dimension 15.
# Error: Embedding for 'took' has incorrect dimension 15.
# Error: Embedding for 'courses' has incorrect dimension 15.
# Error: Embedding for 'photobook' has incorrect dimension 15.
# Error: Embedding for 'young' has incorrect dimension 15.
# Error: Embedding for 'overcooking' has incorrect dimension 15.
# Error: Embedding for 'bumped' has incorrect dimension 15.
# Error: Embedding for 'thier' has incorrect dimension 15.
# Error: Embedding for 'River' has incorrect dimension 15.
# Error: Embedding for 'rolls' has incorrect dimension 15.
# Error: Embedding for 'slaw' has incorrect dimension 15.
# Error: Embedding for 'tiramisu' has incorrect dimension 15.
# Error: Embedding for 'selections' has incorrect dimension 15.
# Error: Embedding for 'Vittorio' has incorrect dimension 15.
# Error: Embedding for 'woman' has incorrect dimension 15.
# Error: Embedding for 'aisle' has incorrect dimension 15.
# Error: Embedding for 'waste' has incorrect dimension 15.
# Error: Embedding for 'plate' has incorrect dimension 15.
# Error: Embedding for 'Paris' has incorrect dimension 15.
# Error: Embedding for 'almost' has incorrect dimension 15.
# Error: Embedding for 'twice' has incorrect dimension 15.
# Error: Embedding for 'Noir' has incorrect dimension 15.
# Error: Embedding for 'chaat' has incorrect dimension 15.
# Error: Embedding for 'walked' has incorrect dimension 15.
# Error: Embedding for 'trang' has incorrect dimension 15.
# Error: Embedding for 'sooo' has incorrect dimension 15.
# Error: Embedding for 'Delivery' has incorrect dimension 15.
# Error: Embedding for 'dazzling' has incorrect dimension 15.
# Error: Embedding for 'sitting' has incorrect dimension 15.
# Error: Embedding for 'filet' has incorrect dimension 15.
# Error: Embedding for 'so-so' has incorrect dimension 15.
# Error: Embedding for 'BY' has incorrect dimension 15.
# Error: Embedding for 'If' has incorrect dimension 15.
# Error: Embedding for 'favorite' has incorrect dimension 15.
# Error: Embedding for 'high' has incorrect dimension 15.
# Error: Embedding for 'best' has incorrect dimension 15.
# Error: Embedding for 'bad' has incorrect dimension 15.
# Error: Embedding for 'tempura' has incorrect dimension 15.
# Error: Embedding for 'Fluke' has incorrect dimension 15.
# Error: Embedding for 'temperatures' has incorrect dimension 15.
# Error: Embedding for 'It' has incorrect dimension 15.
# Error: Embedding for 'awesome' has incorrect dimension 15.
# Error: Embedding for 'cheff' has incorrect dimension 15.
# Error: Embedding for 'fast' has incorrect dimension 15.
# Error: Embedding for 'whip' has incorrect dimension 15.
# Error: Embedding for 'highlight' has incorrect dimension 15.
# Error: Embedding for 'finally' has incorrect dimension 15.
# Error: Embedding for 'Nina' has incorrect dimension 15.
# Error: Embedding for 'unprofessional' has incorrect dimension 15.
# Error: Embedding for 'tikka' has incorrect dimension 15.
# Error: Embedding for 'higher' has incorrect dimension 15.
# Error: Embedding for 'fact' has incorrect dimension 15.
# Error: Embedding for 'speak' has incorrect dimension 15.
# Error: Embedding for 'pizza' has incorrect dimension 15.
# Error: Embedding for 'drank' has incorrect dimension 15.
# Error: Embedding for 'unforgetable' has incorrect dimension 15.
# Error: Embedding for 'management' has incorrect dimension 15.
# Error: Embedding for 'lotus' has incorrect dimension 15.
# Error: Embedding for 'powder' has incorrect dimension 15.
# Error: Embedding for 'gods' has incorrect dimension 15.
# Error: Embedding for 'hike' has incorrect dimension 15.
# Error: Embedding for 'client' has incorrect dimension 15.
# Error: Embedding for 'baked' has incorrect dimension 15.
# Error: Embedding for 'Quick' has incorrect dimension 15.
# Error: Embedding for 'Dosa' has incorrect dimension 15.
# Error: Embedding for 'secluded' has incorrect dimension 15.
# Error: Embedding for 'serves' has incorrect dimension 15.
# Error: Embedding for 'words' has incorrect dimension 15.
# Error: Embedding for 'made' has incorrect dimension 15.
# Error: Embedding for '10-piece' has incorrect dimension 15.
# Error: Embedding for 'charred' has incorrect dimension 15.
# Error: Embedding for 'his' has incorrect dimension 15.
# Error: Embedding for 'its' has incorrect dimension 15.
# Error: Embedding for '3-course' has incorrect dimension 15.
# Error: Embedding for 'we' has incorrect dimension 15.
# Error: Embedding for 'Nice' has incorrect dimension 15.
# Error: Embedding for 'nice' has incorrect dimension 15.
# Error: Embedding for 'crappy' has incorrect dimension 15.
# Error: Embedding for 'evident' has incorrect dimension 15.
# Error: Embedding for 'pleased' has incorrect dimension 15.
# Error: Embedding for 'otherwise' has incorrect dimension 15.
# Error: Embedding for 'decided' has incorrect dimension 15.
# Error: Embedding for '14.00' has incorrect dimension 15.
# Error: Embedding for 'missed' has incorrect dimension 15.
# Error: Embedding for 'wow' has incorrect dimension 15.
# Error: Embedding for 'ground' has incorrect dimension 15.
# Error: Embedding for 'number' has incorrect dimension 15.
# Error: Embedding for 'Knowledge' has incorrect dimension 15.
# Error: Embedding for 'Story' has incorrect dimension 15.
# Error: Embedding for 'escargot' has incorrect dimension 15.
# Error: Embedding for 'crossed' has incorrect dimension 15.
# Error: Embedding for 'comfortable' has incorrect dimension 15.
# Error: Embedding for 'first' has incorrect dimension 15.
# Error: Embedding for 'icy' has incorrect dimension 15.
# Error: Embedding for 'leads' has incorrect dimension 15.
# Error: Embedding for 'wanted' has incorrect dimension 15.
# Error: Embedding for 'ENJOYED' has incorrect dimension 15.
# Error: Embedding for 'Wednesday' has incorrect dimension 15.
# Error: Embedding for 'best-' has incorrect dimension 15.
# Error: Embedding for 'greet' has incorrect dimension 15.
# Error: Embedding for 'Too' has incorrect dimension 15.
# Error: Embedding for 'scores' has incorrect dimension 15.
# Error: Embedding for 'heat' has incorrect dimension 15.
# Error: Embedding for 'Unique' has incorrect dimension 15.
# Error: Embedding for 'mint' has incorrect dimension 15.
# Error: Embedding for 'Kai' has incorrect dimension 15.
# Error: Embedding for 'doing' has incorrect dimension 15.
# Error: Embedding for 'casualness' has incorrect dimension 15.
# Error: Embedding for 'accompaniment' has incorrect dimension 15.
# Error: Embedding for 'helpful' has incorrect dimension 15.
# Error: Embedding for 'drawn' has incorrect dimension 15.
# Error: Embedding for 'questions' has incorrect dimension 15.
# Error: Embedding for 'vegtables' has incorrect dimension 15.
# Error: Embedding for 'emphasis' has incorrect dimension 15.
# Error: Embedding for 'round' has incorrect dimension 15.
# Error: Embedding for 'Consistently' has incorrect dimension 15.
# Error: Embedding for 'clubhouse' has incorrect dimension 15.
# Error: Embedding for 'lay' has incorrect dimension 15.
# Error: Embedding for 'speaking' has incorrect dimension 15.
# Error: Embedding for 'ration' has incorrect dimension 15.
# Error: Embedding for 'chefs' has incorrect dimension 15.
# Error: Embedding for 'however' has incorrect dimension 15.
# Error: Embedding for 'grating' has incorrect dimension 15.
# Error: Embedding for 'bindi' has incorrect dimension 15.
# Error: Embedding for 'Among' has incorrect dimension 15.
# Error: Embedding for 'Mermaid' has incorrect dimension 15.
# Error: Embedding for 'professional' has incorrect dimension 15.
# Error: Embedding for 'calm' has incorrect dimension 15.
# Error: Embedding for 'wines' has incorrect dimension 15.
# Error: Embedding for 'revenue' has incorrect dimension 15.
# Error: Embedding for 'wind' has incorrect dimension 15.
# Error: Embedding for 'mesclun' has incorrect dimension 15.
# Error: Embedding for 'scampi' has incorrect dimension 15.
# Error: Embedding for 'terrace' has incorrect dimension 15.
# Error: Embedding for 'Everything' has incorrect dimension 15.
# Error: Embedding for 'Day' has incorrect dimension 15.
# Error: Embedding for '30+' has incorrect dimension 15.
# Error: Embedding for 'nightcap' has incorrect dimension 15.
# Error: Embedding for 'certain' has incorrect dimension 15.
# Error: Embedding for 'this' has incorrect dimension 15.
# Error: Embedding for 'look' has incorrect dimension 15.
# Error: Embedding for 'forgettable' has incorrect dimension 15.
# Error: Embedding for 'FOUR' has incorrect dimension 15.
# Error: Embedding for 'skiline' has incorrect dimension 15.
# Error: Embedding for 'shredded' has incorrect dimension 15.
# Error: Embedding for 'got' has incorrect dimension 15.
# Error: Embedding for 'A++' has incorrect dimension 15.
# Error: Embedding for 'custards' has incorrect dimension 15.
# Error: Embedding for 'meet' has incorrect dimension 15.
# Error: Embedding for 'until' has incorrect dimension 15.
# Error: Embedding for 'There' has incorrect dimension 15.
# Error: Embedding for 'Have' has incorrect dimension 15.
# Error: Embedding for 'delightful' has incorrect dimension 15.
# Error: Embedding for 'tai' has incorrect dimension 15.
# Error: Embedding for 'excpetiona' has incorrect dimension 15.
# Error: Embedding for 'understated' has incorrect dimension 15.
# Error: Embedding for 'refleshment' has incorrect dimension 15.
# Error: Embedding for 'tiled' has incorrect dimension 15.
# Error: Embedding for 'Kati' has incorrect dimension 15.
# Error: Embedding for 'complementary' has incorrect dimension 15.
# Error: Embedding for 'omelletes' has incorrect dimension 15.
# Error: Embedding for 'balance' has incorrect dimension 15.
# Error: Embedding for 'delicious' has incorrect dimension 15.
# Error: Embedding for 'lacking' has incorrect dimension 15.
# Error: Embedding for 'Pinard' has incorrect dimension 15.
# Error: Embedding for 'hoping' has incorrect dimension 15.
# Error: Embedding for 'Fantastic' has incorrect dimension 15.
# Error: Embedding for 'definitely' has incorrect dimension 15.
# Error: Embedding for 'lively' has incorrect dimension 15.
# Error: Embedding for 'Kind' has incorrect dimension 15.
# Error: Embedding for 'under' has incorrect dimension 15.
# Error: Embedding for 'party' has incorrect dimension 15.
# Error: Embedding for 'Really' has incorrect dimension 15.
# Error: Embedding for 'Every' has incorrect dimension 15.
# Error: Embedding for 'Food' has incorrect dimension 15.
# Error: Embedding for 'trouble' has incorrect dimension 15.
# Error: Embedding for 'deposit' has incorrect dimension 15.
# Error: Embedding for 'repeatable' has incorrect dimension 15.
# Error: Embedding for 'prixe' has incorrect dimension 15.
# Error: Embedding for 'every' has incorrect dimension 15.
# Error: Embedding for 'generation-Fornini' has incorrect dimension 15.
# Error: Embedding for 'holding' has incorrect dimension 15.
# Error: Embedding for 'relaxing' has incorrect dimension 15.
# Error: Embedding for 'wontons' has incorrect dimension 15.
# Error: Embedding for 'various' has incorrect dimension 15.
# Error: Embedding for 'appetizers' has incorrect dimension 15.
# Error: Embedding for 'town' has incorrect dimension 15.
# Error: Embedding for 'Citysearch' has incorrect dimension 15.
# Error: Embedding for 'Frankly' has incorrect dimension 15.
# Error: Embedding for 'seemed' has incorrect dimension 15.
# Error: Embedding for 'that' has incorrect dimension 15.
# Error: Embedding for 'search' has incorrect dimension 15.
# Error: Embedding for 'promised' has incorrect dimension 15.
# Error: Embedding for 'changes' has incorrect dimension 15.
# Error: Embedding for 'want' has incorrect dimension 15.
# Error: Embedding for 'CAREFUL' has incorrect dimension 15.
# Error: Embedding for 'Anywhere' has incorrect dimension 15.
# Error: Embedding for 'poor' has incorrect dimension 15.
# Error: Embedding for 'good' has incorrect dimension 15.
# Error: Embedding for 'jelly' has incorrect dimension 15.
# Error: Embedding for 'Kamikaze' has incorrect dimension 15.
# Error: Embedding for 'laid' has incorrect dimension 15.
# Error: Embedding for 'striped' has incorrect dimension 15.
# Error: Embedding for 'weather' has incorrect dimension 15.
# Error: Embedding for 'Tamari' has incorrect dimension 15.
# Error: Embedding for 'atmoshere' has incorrect dimension 15.
# Error: Embedding for 'air' has incorrect dimension 15.
# Error: Embedding for 'tatin' has incorrect dimension 15.
# Error: Embedding for 'On' has incorrect dimension 15.
# Error: Embedding for '...' has incorrect dimension 15.
# Error: Embedding for 'vault' has incorrect dimension 15.
# Error: Embedding for 'claiming' has incorrect dimension 15.
# Error: Embedding for 'absolutely' has incorrect dimension 15.
# Error: Embedding for 'arrived' has incorrect dimension 15.
# Error: Embedding for 'The' has incorrect dimension 15.
# Error: Embedding for 'with' has incorrect dimension 15.
# Error: Embedding for 'celebrate' has incorrect dimension 15.
# Error: Embedding for 'ATROCIOUS' has incorrect dimension 15.
# Error: Embedding for 'quite' has incorrect dimension 15.
# Error: Embedding for 'So' has incorrect dimension 15.
# Error: Embedding for 'Mai' has incorrect dimension 15.
# FastText embeddings saved to fasttext_embeddings_15.pkl.
